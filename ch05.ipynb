// %% [markdown]
// # JavaScript Hello World Jupyter Notebook

// %%
var msg = "Hello World"
console.log(msg)
// Out:
// Hello World

// %% [markdown]
// # Node.js d3 package

// %%
var fs = require("fs");
var d3 = require("d3");
var _ = require("lodash");

//read in the animals file
fs.readFile("data/animals.tsv", "utf8", function(error, data) {
    data = d3.tsvParse(data);
    //display on screen
    console.log(JSON.stringify(data));
    //compute the maximum weight
    var maxWeight = d3.max(data, function(d) { return d.avg_weight;});
    //display the max on screen
    console.log(maxWeight);
});
// Out:
// [{"name":"lion","avg_weight":"400"},{"name":"tiger","avg_weight":"400"},{"name":"human","avg_weight":"150"},{"name":"elephant","avg_weight":"2000"}]
// 400

// %% [markdown]
// # Node.js stats-analysis package

// %%
var stats__x = require("stats-analysis");
var arr = [98, 98.6, 98.4, 98.8, 200, 120, 98.5];

//standard deviation
var my_stddev = stats__x.stdev(arr).toFixed(2);

//mean
var my_mean = stats__x.mean(arr).toFixed(2);

//median
var my_median = stats__x.median(arr);

//median absolute deviation
var my_mad = stats__x.MAD(arr);

// Get the index locations of the outliers in the data set
var my_outliers = stats__x.indexOfOutliers(arr);

// Remove the outliers
var my_without_outliers = stats__x.filterOutliers(arr);

//display our stats
console.log("Raw data is ", arr);
console.log("Standard Deviation is ", my_stddev);
console.log("Mean is ", my_mean);
console.log("Median is ", my_median);
console.log("Median Abs Deviation is " + my_mad);
console.log("The outliers of the data set are ", my_outliers);
console.log("The data set without outliers is ",
my_without_outliers);
// Out:
// Raw data is  [ 98, 98.6, 98.4, 98.8, 200, 120, 98.5 ]
// Standard Deviation is  35.07
// Mean is  116.04
// Median is  98.6
// Median Abs Deviation is 0.20000000000000284
// The outliers of the data set are  [ 4, 5, 6 ]
// The data set without outliers is  [ 98, 98.6, 98.4, 98.8 ]

// %% [markdown]
// # Node.js JSON handling

// %%
//load the JSON dataset
var fords = require('./data/ford.json');

//display how many Ford models are in our data set
console.log("There are " + fords.Models.length + " Ford models in the data set");

//loop over the set
var index = 1
for(var i=0; i<fords.Models.length; i++) {
    //get this model
    var model = fords.Models[i];
    
    //pull it's name
    var name = model.model_name;
    
    //if the model name does not have numerics in it
    if(! name.match(/[0-9]/i)) {
        
        //display the model name
        console.log("Model " + index + " is a " + name);
        index++;
    }
    
    //only display the first 5
    if (index>5) break;
}
// Out:
// There are 147 Ford models in the data set
// Model 1 is a Aerostar
// Model 2 is a Anglia
// Model 3 is a Artic
// Model 4 is a Aspire
// Model 5 is a Bantam

// %% [markdown]
// # Node.js asynchronous threads

// %%
//thread function - invoked for every number in items array
function async(arg, callback) {
    console.log('cube '+arg+', and return 2 seconds later');
    setTimeout(function() { callback(arg * 3); }, 2000);
}

//function called once - after all threads complete
function final() { console.log('Done', results); }

//list of numbers to operate upon
var items = [ 0, 1, 1, 2, 3, 5, 7, 11 ];

//results of each step
var results = [];

//loop the drives the whole process
items.forEach(function(item) {
    async(item, function(result){
        results.push(result);
        if(results.length == items.length) {
            final();
        }
    })
});
// Out:
// cube 0, and return 2 seconds later
// cube 1, and return 2 seconds later
// cube 1, and return 2 seconds later
// cube 2, and return 2 seconds later
// cube 3, and return 2 seconds later
// cube 5, and return 2 seconds later
// cube 7, and return 2 seconds later
// cube 11, and return 2 seconds later
// Done [ 0, 3, 3, 6, 9, 15, 21, 33 ]

// %% [markdown]
// # Node.js decision-tree package

// %%
//Import the modules
var DecisionTree = require('decision-tree');

var fs = require("fs");
var d3 = require("d3");
var util = require('util');

//read in the car/mpg file
fs.readFile("data/car-mpg.tsv", "utf8", function(error,data){
    //parse out the csv into a dataset
    var dataset = d3.tsvParse(data);
    
    //display on screen - just for debugging
    console.log(JSON.stringify(dataset));
    var rows = dataset.length;
    console.log("rows = " + rows);
    var training_size = rows * 2 / 3;
    console.log("training_size = " + training_size);
    var test_size = rows - training_size;
    console.log("test_size = " + test_size);
    
    //Prepare training dataset
    var training_data = dataset.slice(1, training_size);
    
    //Prepare test dataset
    var test_data = dataset.slice(training_size, rows);
    
    //Setup Target Class used for prediction
    var class_name = "mpg";
    
    //Setup Features to be used by decision tree
    var features = ["cylinders","displacement","horsepower","weight","acceleration", "modelyear", "maker"];
    
    //Create decision tree and train model
    var dt = new DecisionTree(training_data, class_name, features);
    console.log("Decision Tree is " + util.inspect(dt, {showHidden: false, depth: null}));
    
    //Predict class label for an instance
    var predicted_class = dt.predict({
        cylinders: 8,
        displacement: 400,
        horsepower: 200,
        weight: 4000,
        acceleration: 12,
        modelyear: 70,
        maker: "US"
    });
    
    console.log("Predicted Class is " + util.inspect(predicted_class, {showHidden: false, depth: null}));
    
    //Evaluate model on a dataset
    var accuracy = dt.evaluate(test_data);
    console.log("Accuracy is " + accuracy);
    
    //Export underlying model for visualization or inspection
    var treeModel = dt.toJSON();
    console.log("Decision Tree JSON is " + util.inspect(treeModel, {showHidden: false, depth: null}));
});
// Out:
// [{"mpg":"Bad","cylinders":"8","displacement":"350","horsepower":"150","weight":"4699","acceleration":"14.5","modelyear":"74","maker":"America"},{"mpg":"Bad","cylinders":"8","displacement":"400","horsepower":"170","weight":"4746","acceleration":"12","modelyear":"71","maker":"America"},{"mpg":"Bad","cylinders":"8","displacement":"400","horsepower":"175","weight":"4385","acceleration":"12","modelyear":"72","maker":"America"},{"mpg":"Bad","cylinders":"6","displacement":"250","horsepower":"72","weight":"3158","acceleration":"19.5","modelyear":"75","maker":"America"},{"mpg":"Bad","cylinders":"8","displacement":"304","horsepower":"150","weight":"3892","acceleration":"12.5","modelyear":"72","maker":"America"},{"mpg":"Bad","cylinders":"8","displacement":"350","horsepower":"145","weight":"4440","acceleration":"14","modelyear":"75","maker":"America"},{"mpg":"Bad","cylinders":"6","displacement":"250","horsepower":"105","weight":"3897","acceleration":"18.5","modelyear":"75","maker":"America"},{"mpg":"Bad","cylinders":"6","displacement":"163","horsepower":"133","weight":"3410","acceleration":"15.8","modelyear":"78","maker":"Asia"},{"mpg":"Bad","cylinders":"8","displacement":"260","horsepower":"110","weight":"4060","acceleration":"19","modelyear":"77","maker":"America"},{"mpg":"Bad","cylinders":"8","displacement":"305","horsepower":"130","weight":"3840","acceleration":"15.4","modelyear":"79","maker":"America"},{"mpg":"Bad","cylinders":"6","displacement":"250","horsepower":"110","weight":"3520","acceleration":"16.4","modelyear":"77","maker":"America"},{"mpg":"Bad","cylinders":"6","displacement":"258","horsepower":"95","weight":"3193","acceleration":"17.8","modelyear":"76","maker":"America"},{"mpg":"Bad","cylinders":"4","displacement":"121","horsepower":"112","weight":"2933","acceleration":"14.5","modelyear":"72","maker":"Asia"},{"mpg":"Bad","cylinders":"6","displacement":"225","horsepower":"105","weight":"3613","acceleration":"16.5","modelyear":"74","maker":"America"},{"mpg":"Bad","cylinders":"4","displacement":"121","horsepower":"112","weight":"2868","acceleration":"15.5","modelyear":"73","maker":"Asia"},{"mpg":"Bad","cylinders":"6","displacement":"225","horsepower":"95","weight":"3264","acceleration":"16","modelyear":"75","maker":"America"},{"mpg":"Bad","cylinders":"6","displacement":"200","horsepower":"85","weight":"2990","acceleration":"18.2","modelyear":"79","maker":"America"},{"mpg":"OK","cylinders":"4","displacement":"121","horsepower":"98","weight":"2945","acceleration":"14.5","modelyear":"75","maker":"Asia"},{"mpg":"OK","cylinders":"6","displacement":"232","horsepower":"90","weight":"3085","acceleration":"17.6","modelyear":"76","maker":"America"},{"mpg":"OK","cylinders":"4","displacement":"120","horsepower":"97","weight":"2506","acceleration":"14.5","modelyear":"72","maker":"Europe"},{"mpg":"OK","cylinders":"4","displacement":"151","horsepower":"85","weight":"2855","acceleration":"17.6","modelyear":"78","maker":"America"},{"mpg":"OK","cylinders":"4","displacement":"116","horsepower":"75","weight":"2158","acceleration":"15.5","modelyear":"73","maker":"Asia"},{"mpg":"OK","cylinders":"4","displacement":"119","horsepower":"97","weight":"2545","acceleration":"17","modelyear":"75","maker":"Europe"},{"mpg":"OK","cylinders":"6","displacement":"146","horsepower":"120","weight":"2930","acceleration":"13.8","modelyear":"81","maker":"Europe"},{"mpg":"OK","cylinders":"4","displacement":"116","horsepower":"81","weight":"2220","acceleration":"16.9","modelyear":"76","maker":"Asia"},{"mpg":"OK","cylinders":"4","displacement":"156","horsepower":"92","weight":"2620","acceleration":"14.4","modelyear":"81","maker":"America"},{"mpg":"OK","cylinders":"4","displacement":"140","horsepower":"88","weight":"2870","acceleration":"18.1","modelyear":"80","maker":"America"},{"mpg":"OK","cylinders":"4","displacement":"97","horsepower":"60","weight":"1834","acceleration":"19","modelyear":"71","maker":"Asia"},{"mpg":"OK","cylinders":"4","displacement":"134","horsepowe ...
// rows = 42
// training_size = 28
// test_size = 14
// Decision Tree is { data:
//    [ { mpg: 'Bad',
//        cylinders: '8',
//        displacement: '400',
//        horsepower: '170',
//        weight: '4746',
//        acceleration: '12',
//        modelyear: '71',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '8',
//        displacement: '400',
//        horsepower: '175',
//        weight: '4385',
//        acceleration: '12',
//        modelyear: '72',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '250',
//        horsepower: '72',
//        weight: '3158',
//        acceleration: '19.5',
//        modelyear: '75',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '8',
//        displacement: '304',
//        horsepower: '150',
//        weight: '3892',
//        acceleration: '12.5',
//        modelyear: '72',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '8',
//        displacement: '350',
//        horsepower: '145',
//        weight: '4440',
//        acceleration: '14',
//        modelyear: '75',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '250',
//        horsepower: '105',
//        weight: '3897',
//        acceleration: '18.5',
//        modelyear: '75',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '163',
//        horsepower: '133',
//        weight: '3410',
//        acceleration: '15.8',
//        modelyear: '78',
//        maker: 'Asia' },
//      { mpg: 'Bad',
//        cylinders: '8',
//        displacement: '260',
//        horsepower: '110',
//        weight: '4060',
//        acceleration: '19',
//        modelyear: '77',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '8',
//        displacement: '305',
//        horsepower: '130',
//        weight: '3840',
//        acceleration: '15.4',
//        modelyear: '79',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '250',
//        horsepower: '110',
//        weight: '3520',
//        acceleration: '16.4',
//        modelyear: '77',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '258',
//        horsepower: '95',
//        weight: '3193',
//        acceleration: '17.8',
//        modelyear: '76',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '4',
//        displacement: '121',
//        horsepower: '112',
//        weight: '2933',
//        acceleration: '14.5',
//        modelyear: '72',
//        maker: 'Asia' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '225',
//        horsepower: '105',
//        weight: '3613',
//        acceleration: '16.5',
//        modelyear: '74',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '4',
//        displacement: '121',
//        horsepower: '112',
//        weight: '2868',
//        acceleration: '15.5',
//        modelyear: '73',
//        maker: 'Asia' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '225',
//        horsepower: '95',
//        weight: '3264',
//        acceleration: '16',
//        modelyear: '75',
//        maker: 'America' },
//      { mpg: 'Bad',
//        cylinders: '6',
//        displacement: '200',
//        horsepower: '85',
//        weight: '2990',
//        acceleration: '18.2',
//        modelyear: '79',
//        maker: 'America' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '121',
//        horsepower: '98',
//        weight: '2945',
//        acceleration: '14.5',
//        modelyear: '75',
//        maker: 'Asia' },
//      { mpg: 'OK',
//        cylinders: '6',
//        displacement: '232',
//        horsepower: '90',
//        weight: '3085',
//        acceleration: '17.6',
//        modelyear: '76',
//        maker: 'America' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '120',
//        horsepower: '97',
//        weight: '2506',
//        acceleration: '14.5',
//        modelyear: '72',
//        maker: 'Europe' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '151',
//        horsepower: '85',
//        weight: '2855',
//        acceleration: '17.6',
//        modelyear: '78',
//        maker: 'America' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '116',
//        horsepower: '75',
//        weight: '2158',
//        acceleration: '15.5',
//        modelyear: '73',
//        maker: 'Asia' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '119',
//        horsepower: '97',
//        weight: '2545',
//        acceleration: '17',
//        modelyear: '75',
//        maker: 'Europe' },
//      { mpg: 'OK',
//        cylinders: '6',
//        displacement: '146',
//        horsepower: '120',
//        weight: '2930',
//        acceleration: '13.8',
//        modelyear: '81',
//        maker: 'Europe' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '116',
//        horsepower: '81',
//        weight: '2220',
//        acceleration: '16.9',
//        modelyear: '76',
//        maker: 'Asia' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '156',
//        horsepower: '92',
//        weight: '2620',
//        acceleration: '14.4',
//        modelyear: '81',
//        maker: 'America' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '140',
//        horsepower: '88',
//        weight: '2870',
//        acceleration: '18.1',
//        modelyear: '80',
//        maker: 'America' },
//      { mpg: 'OK',
//        cylinders: '4',
//        displacement: '97',
//        horsepower: '60',
//        weight: '1834',
//        acceleration: '19',
//        modelyear: '71',
//        maker: 'Asia' } ],
//   target: 'mpg',
//   features:
//    [ 'cylinders',
//      'displacement',
//      'horsepower',
//      'weight',
//      'acceleration',
//      'modelyear',
//      'maker' ] }
// Predicted Class is 'Bad'
// Accuracy is 0.14285714285714285
// Decision Tree JSON is { name: 'weight',
//   alias: 'weight_r8c4psuphda8',
//   type: 'feature',
//   vals:
//    [ { name: '4746',
//        alias: '4746_r73qnbrtte9',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_repdg9vr8ha8' } },
//      { name: '4385',
//        alias: '4385_r0hof743vfl8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rm8mejlkcjfg' } },
//      { name: '3158',
//        alias: '3158_r5erjq3fft0g',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rdid9rl2it98' } },
//      { name: '3892',
//        alias: '3892_rmrh3dkcvhrg',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rboo41brg588' } },
//      { name: '4440',
//        alias: '4440_rgjd4tddm8e',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rv1vq84vdg0o' } },
//      { name: '3897',
//        alias: '3897_rnr4s6k576t8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_r7equu3vdq5' } },
//      { name: '3410',
//        alias: '3410_r0867a3dvd4o',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rua6lbar6i3' } },
//      { name: '4060',
//        alias: '4060_rt944o57btng',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_r1dajs9l5lgg' } },
//      { name: '3840',
//        alias: '3840_r2e198r72sig',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rugn8otsd0e' } },
//      { name: '3520',
//        alias: '3520_r402hcvmijm',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_r3i0jt7mfp88' } },
//      { name: '3193',
//        alias: '3193_rsu5itakcli8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_r9rkqm1hc328' } },
//      { name: '2933',
//        alias: '2933_r7ivkqipip6g',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rfrk2ho4r0o8' } },
//      { name: '3613',
//        alias: '3613_rt18ghdduug8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_rpmsknhrupro' } },
//      { name: '2868',
//        alias: '2868_rc202u2vrkf8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_r1g90q485ekg' } },
//      { name: '3264',
//        alias: '3264_r06qmj6e1jf8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_r74o96r1hf9o' } },
//      { name: '2990',
//        alias: '2990_rk64k0jq0dco',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'Bad',
//           name: 'Bad',
//           alias: 'Bad_r7uienmchd8o' } },
//      { name: '2945',
//        alias: '2945_rs8pcosotbr',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_roq3u7gssn18' } },
//      { name: '3085',
//        alias: '3085_rbgch5ug0pfg',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rbea57mm49po' } },
//      { name: '2506',
//        alias: '2506_rip0i2c2i2sg',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rffrs6uhocfg' } },
//      { name: '2855',
//        alias: '2855_rejrg9onpncg',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rbfd1el2cmeo' } },
//      { name: '2158',
//        alias: '2158_ridaln7tf9lo',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rea1jevb3jb8' } },
//      { name: '2545',
//        alias: '2545_r7p7oqggjqu8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rervnj87e6ho' } },
//      { name: '2930',
//        alias: '2930_rpj899dg0t0g',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rsrc4eapi0k8' } },
//      { name: '2220',
//        alias: '2220_rng141k3q7q',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rgcm478jf2bg' } },
//      { name: '2620',
//        alias: '2620_r0cle738inv8',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rrcui2g9fcgo' } },
//      { name: '2870',
//        alias: '2870_rg8tcqc335qg',
//        type: 'feature_value',
//        child:
//         { type: 'result',
//           val: 'OK',
//           name: 'OK',
//           alias: 'OK_rbp1gh40sl2o' } },
//      { name: '1834',
//        alias: '1834_rvg335e9sq7g',
//        type: 'feature_value',
//        child: { type: 'result', val: 'OK', name: 'OK', alias: 'OK_rusq0vcuo28' } } ] }
